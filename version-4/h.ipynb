# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.54.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (1.9.0)
# Collecting cachetools<7,>=5.5 (from streamlit)
#   Downloading cachetools-6.2.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (8.3.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging>=20 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (11.3.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (5.29.5)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-23.0.0-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (9.1.4)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (4.14.1)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.10.2)
# Requirement already satisfied: colorama in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.27.0)
# Requirement already satisfied: six>=1.5 in c:\users\ishit\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.54.0-py3-none-any.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.1 MB 840.2 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/9.1 MB 860.9 kB/s eta 0:00:10
#    ---- ----------------------------------- 1.0/9.1 MB 883.6 kB/s eta 0:00:10
#    ---- ----------------------------------- 1.0/9.1 MB 883.6 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/9.1 MB 883.4 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.1 MB 883.2 kB/s eta 0:00:09
#    -------- ------------------------------- 1.8/9.1 MB 923.6 kB/s eta 0:00:08
#    --------- ------------------------------ 2.1/9.1 MB 932.4 kB/s eta 0:00:08
#    ---------- ----------------------------- 2.4/9.1 MB 932.1 kB/s eta 0:00:08
#    ---------- ----------------------------- 2.4/9.1 MB 932.1 kB/s eta 0:00:08
#    ----------- ---------------------------- 2.6/9.1 MB 938.1 kB/s eta 0:00:07
#    ------------ --------------------------- 2.9/9.1 MB 942.6 kB/s eta 0:00:07
#    ------------- -------------------------- 3.1/9.1 MB 946.7 kB/s eta 0:00:07
#    -------------- ------------------------- 3.4/9.1 MB 941.0 kB/s eta 0:00:07
#    -------------- ------------------------- 3.4/9.1 MB 941.0 kB/s eta 0:00:07
#    ---------------- ----------------------- 3.7/9.1 MB 936.2 kB/s eta 0:00:06
#    ----------------- ---------------------- 3.9/9.1 MB 951.0 kB/s eta 0:00:06
#    ------------------ --------------------- 4.2/9.1 MB 953.2 kB/s eta 0:00:06
#    ------------------- -------------------- 4.5/9.1 MB 955.4 kB/s eta 0:00:05
#    -------------------- ------------------- 4.7/9.1 MB 957.1 kB/s eta 0:00:05
#    -------------------- ------------------- 4.7/9.1 MB 957.1 kB/s eta 0:00:05
#    --------------------- ------------------ 5.0/9.1 MB 935.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.1 MB 957.3 kB/s eta 0:00:05
#    ------------------------ --------------- 5.5/9.1 MB 956.0 kB/s eta 0:00:04
#    ------------------------ --------------- 5.5/9.1 MB 956.0 kB/s eta 0:00:04
#    ---------------------------------- ----- 6.0/6.9 MB 493.5 kB/s eta 0:00:02
#    ------------------------------------ --- 6.3/6.9 MB 490.3 kB/s eta 0:00:02
#    ------------------------------------ --- 6.3/6.9 MB 490.3 kB/s eta 0:00:02
#    ------------------------------------- -- 6.6/6.9 MB 493.4 kB/s eta 0:00:01
#    ------------------------------------- -- 6.6/6.9 MB 493.4 kB/s eta 0:00:01
#    ------------------------------------- -- 6.6/6.9 MB 493.4 kB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 493.5 kB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 492.3 kB/s eta 0:00:00
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, smmap, pyarrow, cachetools, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-6.0.0 cachetools-6.2.6 gitdb-4.0.12 gitpython-3.1.46 pyarrow-23.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.54.0 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import streamlit as st
import cv2
import numpy as np
from deepface import DeepFace
from streamlit_webrtc import webrtc_streamer, VideoTransformerBase
# Out:
# 2026-02-10 12:07:38.398 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-02-10 12:07:38.403 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-02-10 12:07:38.406 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-02-10 12:07:38.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:38.642 No runtime found, using MemoryCacheStorageManager

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)
class EmotionDetector(VideoTransformerBase):
    def transform(self, frame):
        img = frame.to_ndarray(format="bgr24")

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        rgb = cv2.cvtColor(gray, cv2.COLOR_GRAY2RGB)

        faces = face_cascade.detectMultiScale(
            gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)
        )

        for (x, y, w, h) in faces:
            face_roi = rgb[y:y+h, x:x+w]

            try:
                result = DeepFace.analyze(
                    face_roi,
                    actions=['emotion'],
                    enforce_detection=False
                )
                emotion = result[0]['dominant_emotion']

                cv2.rectangle(img, (x,y), (x+w,y+h), (0,0,255), 2)
                cv2.putText(
                    img, emotion, (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9,
                    (0,0,255), 2
                )
            except:
                pass

        return img
st.set_page_config(page_title="Facial Mood Detector", layout="centered")
st.title("😐 Facial Mood Detector")
st.write("Real-time emotion detection using webcam")

webrtc_streamer(
    key="emotion-detection",
    video_transformer_factory=EmotionDetector,
    media_stream_constraints={"video": True, "audio": False},
)
# Out:
# 2026-02-10 12:07:43.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.958
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\ishit\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-10 12:07:43.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.977 Session state does not function when running a script without `streamlit run`
# 2026-02-10 12:07:43.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.984 No runtime found, using MemoryCacheStorageManager
# 2026-02-10 12:07:43.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:43.995 No runtime found, using MemoryCacheStorageManager
# 2026-02-10 12:07:44.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:44.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:44.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:44.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:44.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:44.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-10 12:07:44.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NoSessionError                            Traceback (most recent call last)
# Cell In[5], line 40
#      37 st.title("😐 Facial Mood Detector")
#      38 st.write("Real-time emotion detection using webcam")
# ---> 40 webrtc_streamer(
#      41     key="emotion-detection",
#      42     video_transformer_factory=EmotionDetector,
#      43     media_stream_constraints={"video": True, "audio": False},
#      44 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\streamlit_webrtc\component.py:552, in webrtc_streamer(key, mode, rtc_configuration, server_rtc_configuration, frontend_rtc_configuration, media_stream_constraints, desired_playing_state, player_factory, in_recorder_factory, out_recorder_factory, video_frame_callback, audio_frame_callback, queued_video_frames_callback, queued_audio_frames_callback, on_video_ended, on_audio_ended, video_processor_factory, audio_processor_factory, async_processing, video_receiver_size, audio_receiver_size, source_video_track, source_audio_track, sendback_video, sendback_audio, video_html_attrs, audio_html_attrs, translations, on_change, video_transformer_factory, async_transform)
#     542     component_value = component_value_raw
#     544 # HACK: Save the component value in this run to the session state
#     545 # to be restored in the next run because the component values of
#     546 # component instances behind the one which calls `rerun()`
#    (...)    550 # the component value of the second instance will be None in the next run
#     551 # after `rerun()`.
# --> 552 session_info = get_this_session_info()
#     553 run_count = get_script_run_count(session_info) if session_info else None
#     554 if component_value is None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\streamlit_webrtc\session_info.py:32, in get_this_session_info()
#      27 def get_this_session_info() -> Optional[SessionInfo]:
#      28     # The original implementation of SessionState (https://gist.github.com/tvst/036da038ab3e999a64497f42de966a92) has a problem    # noqa: E501
#      29     # as referred to in https://gist.github.com/tvst/036da038ab3e999a64497f42de966a92#gistcomment-3484515,                         # noqa: E501
#      30     # then fixed here.
#      31     # This code only works with streamlit>=0.65, https://gist.github.com/tvst/036da038ab3e999a64497f42de966a92#gistcomment-3418729 # noqa: E501
# ---> 32     session_id = get_session_id()
#      34     if VER_GTE_1_18_0:
#      35         from streamlit.runtime.runtime import Runtime
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\streamlit_webrtc\session_info.py:22, in get_session_id()
#      20 ctx = get_script_run_ctx()
#      21 if ctx is None:
# ---> 22     raise NoSessionError("Failed to get the thread context")
#      24 return ctx.session_id
#
# NoSessionError: Failed to get the thread context
